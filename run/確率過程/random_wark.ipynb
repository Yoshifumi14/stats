# %%
import numpy as np
import scipy as sp
from scipy import stats as st
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
sample=np.random.randint(2,size=15)
array=[0]
i=0
for e in sample: 
    if(e==0):
        i=i-1
    else:
        i=i+1
    array.append(i)
plt.plot(array,"-o")
plt.savefig("random_wark")
